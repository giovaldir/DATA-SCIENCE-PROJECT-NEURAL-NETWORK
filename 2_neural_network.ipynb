# %% [markdown]
# # Create a Basic Neural Network for Image Classification

# %% [markdown]
# ## 1. Import Library and Data

# %%
#@title Code for loading the data
# import libraries 
import tensorflow as tf 
import tensorflow.keras as keras
import numpy as np
import matplotlib.pyplot as plt

# utilities library
import cv2
import os

# !rm -rf jaffe
# !rm -rf __MACOSX
# !rm jaffe.zip
# !wget https://github.com/iqbalbasyar/kickstart_gan/raw/main/jaffe.zip -q
# !unzip -q jaffe.zip 


data_path = 'jaffe'
data_dir_list = os.listdir(data_path)

img_data_list=[]
img_label = []
label_map = {}
i = 0 

for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    label_map[i] = str(dataset)
    
    for img in img_list:
        img_label.append(i)
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(128,128))
        img_data_list.append(input_img_resize)
    i += 1

img_data = np.array(img_data_list)
img_data = img_data.astype('float')
img_data = img_data/255 #normalization
img_label = np.array(img_label)

def getlabel(id):
    return label_map[id]

# %% [markdown]
# **About this Data**:
#
# We will use the Japanese Female Facial Expression (JAFFE) dataset which has 183 images of 10 different female models posing for 6 emotions. The data will be normalized so its value will ranging from 0 to 1.
#
# The label will be denoted as numbers, which follow this mapping :
#
# |    | Expression   |
# |---:|:-------------|
# |  0 | HAPPY         |
# |  1 | SURPRISE          |
# |  2 | FEAR        |
# |  3 | SAD     |
# |  4 | ANGRY        |
# |  5 | DISGUST      |
#
# <details> <summary>Cite the author</summary>
# Michael J. Lyons, Shigeru Akamatsu, Miyuki Kamachi, Jiro Gyoba. Coding Facial Expressions with Gabor Wavelets, 3rd IEEE International Conference on Automatic Face and Gesture Recognition, pp. 200-205 (1998). http://doi.org/10.1109/AFGR.1998.670949 Open access content available at: https://zenodo.org/record/3430156
#
# </details>

# %%
# show the dimension of data and the label
img_data.shape, img_label.shape
# Out:
# ((183, 128, 128, 3), (183,))

# %% [markdown]
# To help you more understand about the data shape, here's an illustration of colored image represented as 3d array.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also visualize a few sample of the data to take a better understanding

# %%
i = 0
plt.imshow(img_data[i])

# %%
print(f"label of the #{i} image is : {img_label[i]}")
print(f"which is translated into : {getlabel(img_label[i])}")
# Out:
# label of the #0 image is : 0
# which is translated into : HAPPY

# %% [markdown]
# ## Data Split (Train Test Split)

# %% [markdown]
# In previous notebook, we tested the model with a number that did not exist in the training data, and see if it can predict correctly. This process of comparing the model performance on training data vs the performance of unseen (test) data is called **Cross Validation**.
#
# Because we cannot easily generate new image and test it into the model, we are going to take several image from train data and use it as test data.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(img_data, img_label, test_size=0.1, random_state=0)

# %%
print(f"The size of training sample : {x_train.shape}")
print(f"The size of test sample : {x_test.shape}")
# Out:
# The size of training sample : (164, 128, 128, 3)
# The size of test sample : (19, 128, 128, 3)

# %% [markdown]
# ___

# %% [markdown]
# ## 2. Create the Model

# %% [markdown]
# In previous notebook, we already created a similar model using keras. Here's the code if you wanted to remember.

# %%
# simple model in previous notebook
model_simple = keras.Sequential()

model_simple.add(keras.layers.Dense(units=1, input_shape=[1]))

model_simple.compile(optimizer='SGD', loss='mean_squared_error')

# %% [markdown]
# Now, we are going to create more complex neural network that can receive image as an input. You might notice the differences on :
# - Flatten Layer
# - Activation
# - Optimizer, loss, metrics

# %%
# create a neural network 
model = keras.Sequential()

model.add(keras.layers.Flatten(input_shape=(128,128,3)) ) # flatten layer, transform 128x128x3 data into 49152*1

model.add(keras.layers.Dense(units = 128, activation='relu') )  #input layer 
model.add(keras.layers.Dense(units = 64, activation='relu') )  # hidden layer 
model.add(keras.layers.Dense(units = 6, activation='softmax') ) # output layer 

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 3. Train the Model

# %%
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 7ms/step - loss: 13.1304 - accuracy: 0.2134
# Epoch 2/100
# 6/6 [==============================] - 0s 6ms/step - loss: 13.0968 - accuracy: 0.1890
# Epoch 3/100
# 6/6 [==============================] - 0s 6ms/step - loss: 5.2387 - accuracy: 0.2134
# Epoch 4/100
# 6/6 [==============================] - 0s 6ms/step - loss: 2.8140 - accuracy: 0.2683
# Epoch 5/100
# 6/6 [==============================] - 0s 6ms/step - loss: 2.4109 - accuracy: 0.2500
# Epoch 6/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8207 - accuracy: 0.3171
# Epoch 7/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9250 - accuracy: 0.4146
# Epoch 8/100
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9880 - accuracy: 0.3354
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0492 - accuracy: 0.3780
# Epoch 10/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6900 - accuracy: 0.4451
# Epoch 11/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7531 - accuracy: 0.4207
# Epoch 12/100
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2085 - accuracy: 0.3963
# Epoch 13/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3996 - accuracy: 0.4939
# Epoch 14/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4033 - accuracy: 0.4512
# Epoch 15/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1376 - accuracy: 0.5793
# Epoch 16/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0561 - accuracy: 0.5854
# Epoch 17/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.3931 - accuracy: 0.4939
# Epoch 18/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0880 - accuracy: 0.5915
# Epoch 19/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.9222 - accuracy: 0.6280
# Epoch 20/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.8218 - accuracy: 0.6646
# Epoch 21/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8716 - accuracy: 0.6768
# Epoch 22/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.8356 - accuracy: 0.6585
# Epoch 23/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6980 - accuracy: 0.7256
# Epoch 24/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2135 - accuracy: 0.5488
# Epoch 25/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1564 - accuracy: 0.6585
# Epoch 26/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0935 - accuracy: 0.5976
# Epoch 27/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2314 - accuracy: 0.5854
# Epoch 28/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9130 - accuracy: 0.6768
# Epoch 29/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1327 - accuracy: 0.5549
# Epoch 30/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7227 - accuracy: 0.5305
# Epoch 31/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0206 - accuracy: 0.6585
# Epoch 32/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4908 - accuracy: 0.8415
# Epoch 33/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4235 - accuracy: 0.8963
# Epoch 34/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4568 - accuracy: 0.8537
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4361 - accuracy: 0.8598
# Epoch 36/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6366 - accuracy: 0.7622
# Epoch 37/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6449 - accuracy: 0.7500
# Epoch 38/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6657 - accuracy: 0.7378
# Epoch 39/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4890 - accuracy: 0.7988
# Epoch 40/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5758 - accuracy: 0.7500
# Epoch 41/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3806 - accuracy: 0.8780
# Epoch 42/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3632 - accuracy: 0.8780
# Epoch 43/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3590 - accuracy: 0.8963
# Epoch 44/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.8841
# Epoch 45/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2884 - accuracy: 0.9085
# Epoch 46/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2536 - accuracy: 0.9268
# Epoch 47/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2257 - accuracy: 0.9573
# Epoch 48/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3046 - accuracy: 0.9207
# Epoch 49/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3155 - accuracy: 0.9024
# Epoch 50/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2651 - accuracy: 0.9329
# Epoch 51/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9512
# Epoch 52/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.9024
# Epoch 53/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9090 - accuracy: 0.7012
# Epoch 54/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2986 - accuracy: 0.9268
# Epoch 55/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2606 - accuracy: 0.9329
# Epoch 56/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2954 - accuracy: 0.9207
# Epoch 57/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3152 - accuracy: 0.9024
# Epoch 58/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.8537
# Epoch 59/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0027 - accuracy: 0.7012
# Epoch 60/100
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4967 - accuracy: 0.5549
# Epoch 61/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.7500 - accuracy: 0.6951
# Epoch 62/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6705 - accuracy: 0.7195
# Epoch 63/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5289 - accuracy: 0.8415
# Epoch 64/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4337 - accuracy: 0.8476
# Epoch 65/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.8780
# Epoch 66/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2737 - accuracy: 0.9329
# Epoch 67/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3337 - accuracy: 0.8720
# Epoch 68/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2808 - accuracy: 0.9085
# Epoch 69/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1921 - accuracy: 0.9756
# Epoch 70/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1917 - accuracy: 0.9573
# Epoch 71/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.9939
# Epoch 72/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 0.9939
# Epoch 73/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1529 - accuracy: 0.9817
# Epoch 74/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9756
# Epoch 75/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9878
# Epoch 76/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1030 - accuracy: 0.9939
# Epoch 77/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9939
# Epoch 78/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0866 - accuracy: 1.0000
# Epoch 79/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.9878
# Epoch 80/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1006 - accuracy: 0.9817
# Epoch 81/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0868 - accuracy: 0.9939
# Epoch 82/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 1.0000
# Epoch 83/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0920 - accuracy: 0.9878
# Epoch 84/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0956 - accuracy: 0.9817
# Epoch 85/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 1.0000
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0868 - accuracy: 0.9939
# Epoch 87/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0788 - accuracy: 0.9939
# Epoch 88/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 89/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9878
# Epoch 90/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 1.0000
# Epoch 91/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0759 - accuracy: 0.9939
# Epoch 92/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1031 - accuracy: 0.9756
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 0.9878
# Epoch 94/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1220 - accuracy: 0.9756
# Epoch 95/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0911 - accuracy: 0.9939
# Epoch 96/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 0.9939
# Epoch 97/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 98/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 99/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 100/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0462 - accuracy: 0.9939

# %% [markdown]
# ## 4. Test the Model

# %% [markdown]
# ### Take sample test data

# %%
# select i-th image as sample
i = 0
sample_image = x_test[i:i+1]

# you can  print the original label for the image 
print(f"original label for the data is : {y_test[i]}")

# or plot the image to validate
plt.imshow(sample_image[0]);
# Out:
# original label for the data is : 3

# %%
# if you are unsure of the label, use this function to see what the label belongs to 
getlabel(3)
# Out:
# 'SAD'

# %% [markdown]
# ### Get the prediction from the model

# %%
# predict sample image
model.predict(sample_image)
# Out:
# array([[1.5873119e-01, 1.0070240e-03, 4.8504267e-02, 7.9113990e-01,
#         6.3253821e-05, 5.5440917e-04]], dtype=float32)

# %%
# use np argmax to get the highest number (most activated) of output layer
np.argmax(model.predict(sample_image))
# Out:
# 3

# %% [markdown]
# ### Evaluate model through all test data
#
# we can also evaluate the whole test data to see what's the accuracy of this model on test data compared to train data

# %%
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1384 - accuracy: 0.9474
# [0.13841067254543304, 0.9473684430122375]

# %% [markdown]
# And there you have it, a neural network to classify 6 types of expression of greyscale image
